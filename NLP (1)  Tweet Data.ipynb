# %%
import re
import nltk

# %%
import string

# %%
def text_low(text):
  return text.lower()

str_first = ' HI. I AM ROWNAK'
text_low(str_first)
# Out:
# ' hi. i am rownak'

# %%
def remove(text):
  res = re.sub(r'\d+','',text)
  return res

str_sec = ' Theere are 3 numbers'

re.search('\aTheere' , str_sec)

remove(str_sec)
# Out:
# ' Theere are  numbers'

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

def Stopwords_learn(text):
  stop_words = set(stopwords.words('english'))
  word_tokens = word_tokenize(text)
  filtered = [word for word in word_tokens if word not in stop_words]
  return filtered

text_1 = " Due to less percentage of attendence we can't move quick towards our goal. So be present from the next class otherwise you will miss the advance topic."

Stopwords_learn(text_1)
# Out:
# ['Due',
#  'less',
#  'percentage',
#  'attendence',
#  'ca',
#  "n't",
#  'move',
#  'quick',
#  'towards',
#  'goal',
#  '.',
#  'So',
#  'present',
#  'next',
#  'class',
#  'otherwise',
#  'miss',
#  'advance',
#  'topic',
#  '.']

# %%
from nltk.stem.porter import PorterStemmer

from nltk.tokenize import word_tokenize

stemmer = PorterStemmer()

def Step_words(text):

  word_tokens = word_tokenize(text)
  filtered = [stemmer.stem(word) for word in word_tokens]
  return filtered

text_1 = " Due to less percentages of attendence we can't move quick towards our goal. So be present from the next class otherwise you will miss the advance topic."

Step_words(text_1)
# Out:
# ['due',
#  'to',
#  'less',
#  'percentag',
#  'of',
#  'attend',
#  'we',
#  'ca',
#  "n't",
#  'move',
#  'quick',
#  'toward',
#  'our',
#  'goal',
#  '.',
#  'so',
#  'be',
#  'present',
#  'from',
#  'the',
#  'next',
#  'class',
#  'otherwis',
#  'you',
#  'will',
#  'miss',
#  'the',
#  'advanc',
#  'topic',
#  '.']

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.stem import WordNetLemmatizer

from nltk.tokenize import word_tokenize

stemmer = WordNetLemmatizer()

def Step_words(text):

  stop_words = set(stopwords.words('english'))
  word_tokens = word_tokenize(re.sub(r'[^\w\s]','',text))
  filtered = [stemmer.lemmatize(word) for word in word_tokens if word not in stop_words]
  return ' '.join(filtered)

text_1 = " Due to less percentages of attendence we can't move quick towards our goal. So be present from the next class otherwise you will miss the advance topic."

Step_words(text_1)
# Out:
# 'Due le percentage attendence cant move quick towards goal So present next class otherwise miss advance topic'

# %%
def pun_remove(text):
  res = re.sub(r'[^\w\s]','',text)
  return res

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
from nltk.tokenize import word_tokenize

from nltk import pos_tag

def pos_tagging(text):
  word_tokens = word_tokenize(text)
  return pos_tag(word_tokens)

text_1 = " Due to less percentages of attendence we can't move quick towards our goal. So be present from the next class otherwise you will miss the advance topic."

pos_tagging(text_1)
# Out:
# [('Due', 'JJ'),
#  ('to', 'TO'),
#  ('less', 'JJR'),
#  ('percentages', 'NNS'),
#  ('of', 'IN'),
#  ('attendence', 'NN'),
#  ('we', 'PRP'),
#  ('ca', 'MD'),
#  ("n't", 'RB'),
#  ('move', 'VB'),
#  ('quick', 'JJ'),
#  ('towards', 'NNS'),
#  ('our', 'PRP$'),
#  ('goal', 'NN'),
#  ('.', '.'),
#  ('So', 'RB'),
#  ('be', 'VB'),
#  ('present', 'JJ'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('next', 'JJ'),
#  ('class', 'NN'),
#  ('otherwise', 'NN'),
#  ('you', 'PRP'),
#  ('will', 'MD'),
#  ('miss', 'VB'),
#  ('the', 'DT'),
#  ('advance', 'NN'),
#  ('topic', 'NN'),
#  ('.', '.')]

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Tweets.csv")
df.head()
# Out:
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  570306133677760513           neutral                        1.0000
# 1  570301130888122368          positive                        0.3486
# 2  570301083672813571           neutral                        0.6837
# 3  570301031407624196          negative                        1.0000
# 4  570300817074462722          negative                        1.0000
#
#   negativereason  negativereason_confidence         airline  \
# 0            NaN                        NaN  Virgin America
# 1            NaN                     0.0000  Virgin America
# 2            NaN                        NaN  Virgin America
# 3     Bad Flight                     0.7033  Virgin America
# 4     Can't Tell                     1.0000  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 0                    NaN     cairdin                 NaN              0
# ...

# %%
data = df[['airline' , 'cleaned_tweet']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-3c2de2c97f2f> in <cell line: 1>()
# ----> 1 data = df[['airline' , 'cleaned_tweet']]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3811             if is_iterator(key):
#    3812                 key = list(key)
# -> 3813             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3814
#    3815         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6068             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6069
# -> 6070         self._raise_if_missing(keyarr, indexer, axis_name)
#    6071
#    6072         keyarr = self.take(indexer)
#
# ...

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-c5d84736ba45> in <cell line: 1>()
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
airline_sentiment = df.groupby(['airline', 'airline_sentiment']).airline_sentiment.count()
airline_sentiment.plot(kind = "bar")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-ddae4390e37e> in <cell line: 1>()
# ----> 1 airline_sentiment = df.groupby(['airline', 'airline_sentiment']).airline_sentiment.count()
#       2 airline_sentiment.plot(kind = "bar")
#
# NameError: name 'df' is not defined

# %%
df.airline_sentiment.value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df.airline.value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df['cleaned_tweet'] = df['text'].apply(Step_words)

# %%
df['cleaned_tweet'] = df['text'].apply(pun_remove)

# %%
df['text']
# Out:
# 0                      @VirginAmerica What @dhepburn said.
# 1        @VirginAmerica plus you've added commercials t...
# 2        @VirginAmerica I didn't today... Must mean I n...
# 3        @VirginAmerica it's really aggressive to blast...
# 4        @VirginAmerica and it's a really big bad thing...
#                                ...
# 14635    @AmericanAir thank you we got on a different f...
# 14636    @AmericanAir leaving over 20 minutes Late Flig...
# 14637    @AmericanAir Please bring American Airlines to...
# 14638    @AmericanAir you have my money, you change my ...
# 14639    @AmericanAir we have 8 ppl so we need 2 know h...
# Name: text, Length: 14640, dtype: object

# %%
df['cleaned_tweet']
# Out:
# 0                         VirginAmerica What dhepburn said
# 1        VirginAmerica plus youve added commercials to ...
# 2        VirginAmerica I didnt today Must mean I need t...
# 3        VirginAmerica its really aggressive to blast o...
# 4        VirginAmerica and its a really big bad thing a...
#                                ...
# 14635    AmericanAir thank you we got on a different fl...
# 14636    AmericanAir leaving over 20 minutes Late Fligh...
# 14637    AmericanAir Please bring American Airlines to ...
# 14638    AmericanAir you have my money you change my fl...
# 14639    AmericanAir we have 8 ppl so we need 2 know ho...
# Name: cleaned_tweet, Length: 14640, dtype: object

# %%
df['experiment'] = df['text'].apply(Stopwords_learn)

# %%
df['experiment']
# Out:
# 0           [@, VirginAmerica, What, @, dhepburn, said, .]
# 1        [@, VirginAmerica, plus, 've, added, commercia...
# 2        [@, VirginAmerica, I, n't, today, ..., Must, m...
# 3        [@, VirginAmerica, 's, really, aggressive, bla...
# 4          [@, VirginAmerica, 's, really, big, bad, thing]
#                                ...
# 14635    [@, AmericanAir, thank, got, different, flight...
# 14636    [@, AmericanAir, leaving, 20, minutes, Late, F...
# 14637    [@, AmericanAir, Please, bring, American, Airl...
# 14638    [@, AmericanAir, money, ,, change, flight, ,, ...
# 14639    [@, AmericanAir, 8, ppl, need, 2, know, many, ...
# Name: experiment, Length: 14640, dtype: object

# %%
df['cleaned_tweet']
df.reset_index(drop=True, inplace = True)
df.head()
# Out:
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  570306133677760513           neutral                        1.0000
# 1  570301130888122368          positive                        0.3486
# 2  570301083672813571           neutral                        0.6837
# 3  570301031407624196          negative                        1.0000
# 4  570300817074462722          negative                        1.0000
#
#   negativereason  negativereason_confidence         airline  \
# 0            NaN                        NaN  Virgin America
# 1            NaN                     0.0000  Virgin America
# 2            NaN                        NaN  Virgin America
# 3     Bad Flight                     0.7033  Virgin America
# 4     Can't Tell                     1.0000  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 0                    NaN     cairdin                 NaN              0
# ...

# %%
df.head()
# Out:
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  570306133677760513           neutral                        1.0000
# 1  570301130888122368          positive                        0.3486
# 2  570301083672813571           neutral                        0.6837
# 3  570301031407624196          negative                        1.0000
# 4  570300817074462722          negative                        1.0000
#
#   negativereason  negativereason_confidence         airline  \
# 0            NaN                        NaN  Virgin America
# 1            NaN                     0.0000  Virgin America
# 2            NaN                        NaN  Virgin America
# 3     Bad Flight                     0.7033  Virgin America
# 4     Can't Tell                     1.0000  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 0                    NaN     cairdin                 NaN              0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14640 entries, 0 to 14639
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   tweet_id                      14640 non-null  int64
#  1   airline_sentiment             14640 non-null  object
#  2   airline_sentiment_confidence  14640 non-null  float64
#  3   negativereason                9178 non-null   object
#  4   negativereason_confidence     10522 non-null  float64
#  5   airline                       14640 non-null  object
#  6   airline_sentiment_gold        40 non-null     object
#  7   name                          14640 non-null  object
#  8   negativereason_gold           32 non-null     object
#  9   retweet_count                 14640 non-null  int64
#  10  text                          14640 non-null  object
#  11  tweet_coord                   1019 non-null   object
# ...

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'tweet_id'}>,
#         <Axes: title={'center': 'airline_sentiment_confidence'}>],
#        [<Axes: title={'center': 'negativereason_confidence'}>,
#         <Axes: title={'center': 'retweet_count'}>]], dtype=object)

# %% [markdown]
# vectorization

# %%
a = 'hi'
b = 'doing'
c = 'us'

string = [a,b,c]

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
vec = TfidfVectorizer(use_idf=True, lowercase=False)

# %%
result = vec.fit_transform(df.cleaned_tweet)

# %%
df.head()
# Out:
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  570306133677760513           neutral                        1.0000
# 1  570301130888122368          positive                        0.3486
# 2  570301083672813571           neutral                        0.6837
# 3  570301031407624196          negative                        1.0000
# 4  570300817074462722          negative                        1.0000
#
#   negativereason  negativereason_confidence         airline  \
# 0            NaN                        NaN  Virgin America
# 1            NaN                     0.0000  Virgin America
# 2            NaN                        NaN  Virgin America
# 3     Bad Flight                     0.7033  Virgin America
# 4     Can't Tell                     1.0000  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 0                    NaN     cairdin                 NaN              0
# ...

# %%
from sklearn import preprocessing
label = preprocessing.LabelEncoder()

df['airline_sentiment'] = label.fit_transform(df['airline_sentiment'])
df['airline_sentiment'].unique()
# Out:
# array([1, 2, 0])

# %%
from sklearn.model_selection import train_test_split
from mlxtend.plotting import plot_confusion_matrix

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
import matplotlib.pyplot as plt

from sklearn import svm
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression

from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import mutual_info_classif

# %%
x_train, x_test, y_train, y_test = train_test_split(x, df['airline_sentiment'],test_size = 0.25,random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-5847fa458e39> in <cell line: 1>()
# ----> 1 x_train, x_test, y_train, y_test = train_test_split(x, df['airline_sentiment'],test_size = 0.25,random_state=42)
#
# NameError: name 'x' is not defined

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout

# %%
vocab_size = 10000  # Adjustable based on your vocabulary size
max_sequence_length = 20  # Adjustable based on your desired sequence length
embedding_dim = 100
lstm_units = 64
num_classes = 3

# %%
categorical_labels = tf.keras.utils.to_categorical(df['airline_sentiment'], num_classes=num_classes)

# %%
tokenizer = Tokenizer(num_words=vocab_size, oov_token="<OOV>")
tokenizer.fit_on_texts(df['cleaned_tweet'])
sequences = tokenizer.texts_to_sequences(df['cleaned_tweet'])

# %%
padded_sequences = pad_sequences(sequences, maxlen=max_sequence_length, padding="post", truncating="post")

# %%
model = Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_sequence_length),
    tf.keras.layers.Conv1D(filters=32, kernel_size=5, strides=1, padding="causal", activation="relu",input_shape=[None,64]),
    tf.keras.layers.LSTM(lstm_units),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(num_classes, activation='softmax')
])

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(padded_sequences, categorical_labels, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 458/458 [==============================] - 22s 42ms/step - loss: 0.6608 - accuracy: 0.7221
# Epoch 2/10
# 458/458 [==============================] - 17s 37ms/step - loss: 0.4428 - accuracy: 0.8323
# Epoch 3/10
# 458/458 [==============================] - 18s 40ms/step - loss: 0.3201 - accuracy: 0.8853
# Epoch 4/10
# 458/458 [==============================] - 17s 37ms/step - loss: 0.2382 - accuracy: 0.9178
# Epoch 5/10
# 458/458 [==============================] - 17s 37ms/step - loss: 0.1739 - accuracy: 0.9411
# Epoch 6/10
# 458/458 [==============================] - 16s 36ms/step - loss: 0.1281 - accuracy: 0.9568
# Epoch 7/10
# 458/458 [==============================] - 16s 36ms/step - loss: 0.0949 - accuracy: 0.9704
# Epoch 8/10
# 458/458 [==============================] - 16s 36ms/step - loss: 0.0738 - accuracy: 0.9771
# Epoch 9/10
# 458/458 [==============================] - 18s 40ms/step - loss: 0.0606 - accuracy: 0.9821
# Epoch 10/10
# ...

# %%
from sklearn.naive_bayes import GaussianNB

nb = GaussianNB()
nb_y_pre = cross_val_predict(nb,x, df['airline_sentiment'], cv=10)
nb_sc = accuracy_score(df['airline_sentiment'], nb_y_pre) * 100
nb_sc = "{:.2f}".format(nb_sc)
print(nb_sc)
# Out:
# 51.67

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14640 entries, 0 to 14639
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   tweet_id                      14640 non-null  int64
#  1   airline_sentiment             14640 non-null  object
#  2   airline_sentiment_confidence  14640 non-null  float64
#  3   negativereason                9178 non-null   object
#  4   negativereason_confidence     10522 non-null  float64
#  5   airline                       14640 non-null  object
#  6   airline_sentiment_gold        40 non-null     object
#  7   name                          14640 non-null  object
#  8   negativereason_gold           32 non-null     object
#  9   retweet_count                 14640 non-null  int64
#  10  text                          14640 non-null  object
#  11  tweet_coord                   1019 non-null   object
# ...

# %%
df['airline'].hist()
# Out:
# <Axes: >

# %%
data = [df['airline'],df['cleaned_tweet']]

# %%
from sklearn.linear_model import LogisticRegression

#logisrtic regression classifier

lg = LogisticRegression(random_state=0)
lg_y_pre = cross_val_predict(lg, x, df['airline_sentiment'], cv=10)
lg_sc = accuracy_score(df['airline_sentiment'], lg_y_pre) * 100
lg_sc = "{:.2f}".format(lg_sc)
print(lg_sc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-57607f945cd6> in <cell line: 6>()
#       4
#       5 lg = LogisticRegression(random_state=0)
# ----> 6 lg_y_pre = cross_val_predict(lg, x, df['airline_sentiment'], cv=10)
#       7 lg_sc = accuracy_score(df['airline_sentiment'], lg_y_pre) * 100
#       8 lg_sc = "{:.2f}".format(lg_sc)
#
# NameError: name 'cross_val_predict' is not defined

# %%
vec.vocabulary_
# Out:
# {'VirginAmerica': 7528,
#  'What': 7658,
#  'dhepburn': 10335,
#  'said': 16871,
#  'plus': 15830,
#  'youve': 19517,
#  'added': 7962,
#  'commercials': 9615,
#  'to': 18300,
#  'the': 18116,
#  'experience': 11020,
#  'tacky': 17957,
#  'didnt': 10351,
#  'today': 18305,
#  'Must': 5374,
#  'mean': 14581,
#  'need': 14965,
#  'take': 17970,
#  'another': 8277,
#  'trip': 18485,
#  'its': 13871,
#  'really': 16308,
#  'aggressive': 8053,
#  'blast': 8869,
#  'obnoxious': 15221,
#  'entertainment': 10851,
#  'in': 13582,
#  'your': 19502,
#  'guests': 11884,
#  'faces': 11073,
#  'amp': 8222,
#  'they': 18150,
#  'have': 12001,
#  'little': 14285,
#  'recourse': 16368,
#  'and': 8240,
#  'big': 8819,
#  'bad': 8603,
#  'thing': 18163,
#  'about': 7875,
#  'it': 13853,
#  'seriously': 17086,
#  'would': 19395,
#  'pay': 15609,
#  '30': 834,
#  'flight': 11303,
#  'for': 11445,
#  'seats': 17008,
#  'that': 18108,
#  'this': 18179,
#  'playing': 15797,
#  'only': 15328,
# ...

# %%
result
# Out:
# <14640x19547 sparse matrix of type '<class 'numpy.float64'>'
# 	with 232349 stored elements in Compressed Sparse Row format>

# %%
x = result.toarray()
